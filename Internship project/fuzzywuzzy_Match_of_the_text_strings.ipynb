# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekmishra-bareilly/Machine-learning/blob/main/fuzzywuzzy_Match_of_the_text_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #create code to label each study title (Column A) by matching text against the list of causes (Column S) - calculate the % match of the text strings (between the Title and Cause)  -

# %%
# install fuzzywuzzy
# !pip install requests fuzzywuzzy pandas pyjstat numpy plotly matplotlib seaborn geopy google folium pandas googlemaps

# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /usr/local/lib/python3.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Connect the file by using google drive**

# %%
# connect google drive to run the file
from google.colab import drive #connect with google drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
# file path reading or csv upload to coolab from drive
file_path='/content/Drive/MyDrive/Colab Notebooks/Machine Learning/ML Project/Public and Scientific Study Tit/Public and Scientific Study Tit3.csv'       
string_matching = pd.read_csv(file_path,encoding='latin1')
string_matching = string_matching[:254]
string_matching
# Out:
#                                                  Title  \
# 0    Study of Efficacy and Safety of Two Secukinuma...
# 1                Amroid tablets and ointments in Piles
# 2    It is a study in which the different outside r...
# 3    A study to assess the usefulness of a block te...
# 4    Evaluation of the association between the Ging...
# ..                                                 ...
# 249      Yoga for People Suffering from Drug Addiction
# 250  Test for assessing proprioception(joint positi...
# 251             Effect of NiKu plus in reducing fever.
# 252  Compare the effect of Shatapushpa Powder and K...
# 253  Chemoradiation for advanced unresectable esoph...
#
#                          List of Causes
# 0                         Acne vulgaris
# 1                       Acute hepatitis
# 2               Acute lymphoid leukemia
# 3                Acute myeloid leukemia
# 4    Age-related and other hearing loss
# ..                                  ...
# ...

# %%
string_matching.describe()
# Out:
#                                                     Title List of Causes
# count                                                 254            254
# unique                                                254            254
# top     Study of Efficacy and Safety of Two Secukinuma...  Acne vulgaris
# freq                                                    1              1

# %%
# we try to split the columns 
column_a, column_s = string_matching['Title'], string_matching['List of Causes']

# %% [markdown]
# **Using fuzzywuzzy function**

# %%
# Creating a function using fuzzywuzzy process
def get_matches(q,choices,limit=254):
  result = process.extract(q,choices,limit=limit)
  return result

# %% [markdown]
# **Now we can find the string maching % for each row**

# %%
# String maching for first row of column A.
get_matches(column_a[1],column_s)
# Out:
# [('Colon and rectum cancer', 86, 42),
#  ('Conflict and terrorism', 86, 44),
#  ('Foreign body in eyes', 86, 87),
#  ('Gastritis and duodenitis', 86, 94),
#  ('Myelodysplastic, myeloproliferative, and other hematopoietic neoplasms',
#   86,
#   153),
#  ('Neonatal encephalopathy due to birth asphyxia and trauma', 86, 160),
#  ('Typhoid and paratyphoid', 86, 234),
#  ('Rabies', 57, 200),
#  ('Unintentional injuries', 54, 236),
#  ('Paralytic ileus and intestinal obstruction', 53, 184),
#  ('Syphilis', 53, 220),
#  ("Alzheimer's disease and other dementias", 52, 8),
#  ('Diabetes and kidney diseases', 52, 57),
#  ('Tetanus', 51, 223),
#  ('Sense organ diseases', 50, 210),
#  ('Measles', 49, 143),
#  ('Scabies', 49, 206),
#  ('Urinary diseases and male infertility', 49, 238),
#  ('Enteric infections', 47, 76),
#  ('Cirrhosis and other chronic liver diseases', 46, 40),
#  ('Neonatal sepsis and other neonatal infections', 46, 162),
#  ('Blindness and vision loss', 45, 23),
# ...
